# %%
import uproot
import matplotlib.pyplot as plt
import mplhep as hep
import numpy as np

# %%
edgec = "blue"
fillc = "lightblue"

edgec = "blue"
fillc = "lightblue"

# %% [markdown]
# ## sel vs gen

# %%
file = uproot.open("sel_vs_gen.root")
print(file.keys())
print(file.classnames())
sel_hist = file[file.keys()[0]]
gen_hist = file[file.keys()[1]]


sel_hist_val = sel_hist.values()
gen_hist_val = gen_hist.values()

sel_hist_edges = sel_hist.axis().edges()
gen_hist_edges = gen_hist.axis().edges()

# print(len(sel_hist_val))
print(sel_hist_edges[0])
print(sel_hist_edges[-1])

print(gen_hist_edges[0])
print(gen_hist_edges[-1])
# Out:
# ['sel;1', 'gen;1']
# {'sel;1': 'TH1D', 'gen;1': 'TH1D'}
# 60.0
# 100.0
# 60.0
# 100.0

# %%
f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

# hep.histplot(sel_hist_val[15:-15], bins=sel_hist_edges[15:-15], ax=axs, density=True, histtype="fill", label="selected triplet", linewidth=2, edgecolor="blue", color="lightblue")
hep.histplot(gen_hist_val, bins=gen_hist_edges, ax=axs, density=True, histtype="fill", label="generated signal", linewidth=2, edgecolor="red", color="peachpuff")

plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$m_{3\pi}$ (GeV/$c^2$)', fontsize='20')
plt.ylabel('Normalized Events/2 GeV/$c^2$', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='plain', scilimits=(0, 0), useOffset=False, useMathText=True)
# plt.gca().yaxis.get_offset_text().set_position((-0.07,1))
# plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()


plt.savefig("figures/gen_in_acceptance.pdf", dpi=150)
# plt.savefig("figures/selected_signal.pdf", dpi=150)
# plt.savefig("figures/selected_signal.pdf", dpi=150)
# Out:
# /home/pietro/anaconda3/envs/root-env/lib/python3.8/site-packages/mplhep/utils.py:240: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   self.errors()

# %% [markdown]
# ## reco vs gen

# %%
file_name = "my_reco_vs_gen"
file = uproot.open(file_name + ".root")
print(file.keys())
print(file.classnames())
reco_hist = file[file.keys()[0]]
gen_hist = file[file.keys()[1]]

reco_hist_val = reco_hist.values()
gen_hist_val = gen_hist.values()

reco_hist_edges = reco_hist.axis().edges()
gen_hist_edges = gen_hist.axis().edges()
# Out:
# ['reco;1', 'gen;1']
# {'reco;1': 'TH1D', 'gen;1': 'TH1D'}

# %%
f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(reco_hist_val, bins=reco_hist_edges, ax=axs, density=False, histtype="step", label="reco triplets", linewidth=2, edgecolor="blue", color="lightblue")
hep.histplot(gen_hist_val,  bins=gen_hist_edges,  ax=axs, density=False, histtype="step", label="generated signal", linewidth=2, edgecolor="orange")

plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$m_{3\pi}$ (GeV/$c^2$)', fontsize='20')
plt.ylabel('Normalized Events/2 GeV/$c^2$', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='plain', scilimits=(0, 0), useOffset=False, useMathText=True)
# plt.gca().yaxis.get_offset_text().set_position((-0.07,1))
# plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()


# plt.savefig("figures/reco_vs_gen.pdf", dpi=150)
# plt.savefig("figures/gen_in_acceptance.pdf", dpi=150)

# %% [markdown]
# ## sel vs match

# %%
file_name = "../histograms/InvMass(20,15,12)_MassF(1)_iso(1)_best1.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
sel_hist = file[file.keys()[0]]
match_hist = file[file.keys()[1]]

sel_hist_val = sel_hist.values()
match_hist_val = match_hist.values()

sel_hist_edges = sel_hist.axis().edges()
match_hist_edges = match_hist.axis().edges()
# Out:
# ['selected;1', 'matched;1']
# {'selected;1': 'TH1D', 'matched;1': 'TH1D'}

# %%
len(match_hist_val)
match_hist_edges
# Out:
# array([ 50. ,  50.5,  51. ,  51.5,  52. ,  52.5,  53. ,  53.5,  54. ,
#         54.5,  55. ,  55.5,  56. ,  56.5,  57. ,  57.5,  58. ,  58.5,
#         59. ,  59.5,  60. ,  60.5,  61. ,  61.5,  62. ,  62.5,  63. ,
#         63.5,  64. ,  64.5,  65. ,  65.5,  66. ,  66.5,  67. ,  67.5,
#         68. ,  68.5,  69. ,  69.5,  70. ,  70.5,  71. ,  71.5,  72. ,
#         72.5,  73. ,  73.5,  74. ,  74.5,  75. ,  75.5,  76. ,  76.5,
#         77. ,  77.5,  78. ,  78.5,  79. ,  79.5,  80. ,  80.5,  81. ,
#         81.5,  82. ,  82.5,  83. ,  83.5,  84. ,  84.5,  85. ,  85.5,
#         86. ,  86.5,  87. ,  87.5,  88. ,  88.5,  89. ,  89.5,  90. ,
#         90.5,  91. ,  91.5,  92. ,  92.5,  93. ,  93.5,  94. ,  94.5,
#         95. ,  95.5,  96. ,  96.5,  97. ,  97.5,  98. ,  98.5,  99. ,
#         99.5, 100. , 100.5, 101. , 101.5, 102. , 102.5, 103. , 103.5,
#        104. , 104.5, 105. , 105.5, 106. , 106.5, 107. , 107.5, 108. ,
#        108.5, 109. , 109.5, 110. ])

# %%
f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(sel_hist_val[18:-18],  bins=sel_hist_edges[18:-18],   ax=axs, density=False, histtype="fill", label="selected triplets", linewidth=2, edgecolor="blue", color="lightblue")
# hep.histplot(match_hist_val[18:-18],bins=match_hist_edges[18:-18], ax=axs, density=False, histtype="step", label="matched signal",    linewidth=1.6, edgecolor="red")

plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$m_{3\pi}$ (GeV/$c^2$)', fontsize='20')
plt.ylabel('Events/2 GeV/$c^2$', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='plain', scilimits=(0, 0), useOffset=False, useMathText=True)
# plt.gca().yaxis.get_offset_text().set_position((-0.07,1))
# plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()


# plt.savefig("figures/sel_vs_match.pdf", dpi=150)
plt.savefig("figures/selected_signal.pdf", dpi=150)

# %% [markdown]
# ## no Iso Filter

# %%
file_name = "../histograms/InvMass(20,15,12)_MassF(1)_iso(0)_best1.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
sel_hist = file[file.keys()[0]]
match_hist = file[file.keys()[1]]

sel_hist_val = sel_hist.values()
match_hist_val = match_hist.values()

sel_hist_edges = sel_hist.axis().edges()
match_hist_edges = match_hist.axis().edges()
# Out:
# ['selected;1', 'matched;1']
# {'selected;1': 'TH1D', 'matched;1': 'TH1D'}

# %%
f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(sel_hist_val[15:-15],  bins=sel_hist_edges[15:-15],   ax=axs, density=False, histtype="fill", label="selected triplets", linewidth=2, edgecolor="blue", color="lightblue")
hep.histplot(match_hist_val[15:-15],bins=match_hist_edges[15:-15], ax=axs, density=False, histtype="step", label="matched signal",    linewidth=2, edgecolor="red")

plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$m_{3\pi}$ (GeV/$c^2$)', fontsize='20')
plt.ylabel('Events/2 GeV/$c^2$', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='plain', scilimits=(0, 0), useOffset=False, useMathText=True)
# plt.gca().yaxis.get_offset_text().set_position((-0.07,1))
# plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()


plt.savefig("figures/sel_vs_match_NoIso.pdf", dpi=150)

# %% [markdown]
# ## no Pt Filter

# %%
file_name = "../histograms/InvMass(15,12,4)_MassF(1)_iso(1)_best1.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
sel_hist = file[file.keys()[0]]
match_hist = file[file.keys()[1]]

sel_hist_val = sel_hist.values()
match_hist_val = match_hist.values()

sel_hist_edges = sel_hist.axis().edges()
match_hist_edges = match_hist.axis().edges()
# Out:
# ['selected;1', 'matched;1']
# {'selected;1': 'TH1D', 'matched;1': 'TH1D'}

# %%
f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(sel_hist_val[15:-15],  bins=sel_hist_edges[15:-15],   ax=axs, density=False, histtype="fill", label="selected triplets", linewidth=1.8, edgecolor="blue", color="lightblue", zorder=0)
hep.histplot(match_hist_val[15:-15],bins=match_hist_edges[15:-15], ax=axs, density=False, histtype="step", label="matched signal",    linewidth=2, edgecolor="red")

plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$m_{3\pi}$ (GeV/$c^2$)', fontsize='20')
plt.ylabel('Events/ 2 GeV/$c^2$', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='plain', scilimits=(0, 0), useOffset=False, useMathText=True)
# plt.gca().yaxis.get_offset_text().set_position((-0.07,1))
# plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()


plt.savefig("figures/sel_vs_match_Nopt.pdf", dpi=150)

# %% [markdown]
# # Recostruction

# %%
file_name = "../histograms/Resolution_pt_All.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
res_hist = file[file.keys()[0]]
res_hist_val = res_hist.values()
res_hist_edges = res_hist.axis().edges()

f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(res_hist_val[15:-15],  bins=res_hist_edges[15:-15], ax=axs, density=False, histtype="fill", label="resected triplets", linewidth=1.8, edgecolor="blue", color="lightblue", zorder=0)

# plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('(gen-reco)/gen', fontsize='20')
plt.ylabel('Entries', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useOffset=False, useMathText=True)
plt.gca().yaxis.get_offset_text().set_position((-0.06,1))
plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()

plt.text(0.05, 7500, "resolution $p_T>2$ \n    $\mu = 0.0053$\n    $\sigma = 0.0389$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))

plt.savefig("figures/Resolution_all_pt.pdf", dpi=150)
# Out:
# ['signal;1']
# {'signal;1': 'TH1D'}

# %%
file_name = "../histograms/mass_resolution.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
res_hist = file[file.keys()[0]]
res_hist_val = res_hist.values()
res_hist_edges = res_hist.axis().edges()

f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(res_hist_val[15:-15],  bins=res_hist_edges[15:-15], ax=axs, density=False, histtype="fill", label="resected triplets", linewidth=1.8, edgecolor="blue", color="lightblue", zorder=0)

# plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('(gen-reco)/gen', fontsize='20')
plt.ylabel('Entries', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useOffset=False, useMathText=True)
plt.gca().yaxis.get_offset_text().set_position((-0.06,1))
plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()

plt.text(0.05, 1500, "resolution $p_T>2$ \n     $\mu = 0.0033$\n     $\sigma = 0.0217$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'), fontstyle="italic")

plt.savefig("figures/Resolution_mass.pdf", dpi=150)
# Out:
# ['signal;1']
# {'signal;1': 'TH1D'}

# %% [markdown]
# # Efficiency

# %%
file_name = "../histograms/Efficiency_All.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
gen_hist = file[file.keys()[0]]
reco_hist = file[file.keys()[1]]

gen_hist_val = gen_hist.values()
reco_hist_val = reco_hist.values()

gen_hist_edges = gen_hist.axis().edges()
reco_hist_edges = reco_hist.axis().edges()
# Out:
# ['Gen_pt;1', 'Matched_pt;1']
# {'Gen_pt;1': 'TH1D', 'Matched_pt;1': 'TH1D'}

# %%
f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(gen_hist_val[1:],  bins=gen_hist_edges[1:],   ax=axs, yerr=np.sqrt(gen_hist_val[1:]),density=False, histtype="fill", label="generated pions", linewidth=1.8, edgecolor="blue", color="lightblue", zorder=0)
hep.histplot(reco_hist_val[1:], bins=reco_hist_edges[1:],  ax=axs, yerr=np.sqrt(reco_hist_val[1:]),density=False, histtype="fill", label="reconstructed pions", linewidth=2, edgecolor="red", color="peachpuff")

plt.legend(loc='upper right', frameon=False, title='$p_{T}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$p_{T}$ (GeV)', fontsize='20')
plt.ylabel('Events', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='plain', scilimits=(0, 0), useOffset=False, useMathText=True)
# plt.gca().yaxis.get_offset_text().set_position((-0.07,1))
# plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()


plt.savefig("figures/efficiency_hist.pdf", dpi=150)

# %% [markdown]
# ## efficiency scatter plot

# %%
efficiency = np.divide(reco_hist_val[1:],gen_hist_val[1:])
ranges = np.arange(2,60,2)
print(len(efficiency))
print(len(ranges))
print(len(reco_hist_val[1:]))
efficiency
# Out:
# 29
# 29
# 29
# array([0.65148165, 0.67018122, 0.71000535, 0.69109056, 0.6760816 ,
#        0.67332917, 0.71190977, 0.70549789, 0.71548436, 0.6960896 ,
#        0.70442041, 0.72591006, 0.73054494, 0.73858199, 0.7432304 ,
#        0.74805122, 0.75763547, 0.76866252, 0.76918948, 0.77414075,
#        0.79548023, 0.77373418, 0.78806584, 0.76358696, 0.75700935,
#        0.73305085, 0.82857143, 0.79141104, 0.77037037])

# %%
error_bar1 = np.sqrt(gen_hist_val[1:])
error_bar2 = np.sqrt(reco_hist_val[1:])

e1 = np.divide(error_bar1 , gen_hist_val[1:])
e2 = np.divide(error_bar2 , reco_hist_val[1:])

error_eff = []

for i in range(len(error_bar1)):
    err = np.sqrt(e1[i]**2 + e2[i]**2)
    error_eff.append(efficiency[i] * err)
# error_division = efficiency * np.sqrt((error_bar1 / gen_hist_val[2:])^2 + (error_bar2 / reco_hist_val[2:])^2)

# %%
len(error_eff)
# Out:
# 29

# %%
hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))
plt.ticklabel_format(axis='y', style='plain', scilimits=(0, 0), useOffset=False, useMathText=True)

plt.scatter(ranges, efficiency)
plt.plot(ranges, efficiency)
plt.errorbar(ranges, efficiency, yerr=error_eff, fmt="o", color='blue')

# plt.legend(loc='upper right', frameon=False, title='$p_{T}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$p_{T}$ intervals(GeV)', fontsize='18')
plt.ylabel('Efficiency', fontsize='20')
plt.ylim([0.5,1])
plt.tick_params(axis='both', labelsize=16) 
plt.savefig("figures/efficiency_vs_pt.pdf", dpi=150)

# %% [markdown]
# # resolution histos

# %%
file_name = "../histograms/Resolution_pt.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
# Out:
# ['5_10;1', '10_20;1', '20_30;1', '30_60;1', '60_100;1']
# {'5_10;1': 'TH1D', '10_20;1': 'TH1D', '20_30;1': 'TH1D', '30_60;1': 'TH1D', '60_100;1': 'TH1D'}

# %%
index = 4
res_hist = file[file.keys()[index]]
res_hist_val = res_hist.values()
res_hist_edges = res_hist.axis().edges()

f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(res_hist_val,  bins=res_hist_edges, ax=axs, density=False, histtype="fill", label="resected triplets", linewidth=1.8, edgecolor="blue", color="lightblue", zorder=0)

# plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('(gen-reco)/gen', fontsize='20')
plt.ylabel('Entries', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useOffset=False, useMathText=True)
plt.gca().yaxis.get_offset_text().set_position((-0.06,1))
plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()

plt.text(0.1, 150, "resolution $60<p_T<100$ \n    $\mu = 0.0065$\n    $\sigma = 0.0649$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
# plt.text(0.05, 2250, "resolution $30<p_T<60$ \n    $\mu = 0.0066$\n    $\sigma = 0.0429$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
# plt.text(0.05, 2750, "resolution $20<p_T<30$ \n    $\mu = 0.0058$\n    $\sigma = 0.0366$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
# plt.text(0.05, 2750, "resolution $10<p_T<20$ \n    $\mu = 0.0048$\n    $\sigma = 0.0319$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
# plt.text(0.05, 2750, "resolution $5<p_T<10$ \n    $\mu = 0.0030$\n    $\sigma = 0.0396$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))

plt.savefig("figures/Resolution_pt_60_100.pdf", dpi=150)

# %% [markdown]
# # Feature distribution

# %%
file_name = "../histograms/hist_features.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
# Out:
# ['pt;1', 'eta;1', 'phi;1']
# {'pt;1': 'TH1F', 'eta;1': 'TH1F', 'phi;1': 'TH1F'}

# %% [markdown]
# ## pt

# %%
pt_hist = file[file.keys()[0]]
pt_hist_val = pt_hist.values()
pt_hist_edges = pt_hist.axis().edges()

f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(pt_hist_val,  bins=pt_hist_edges, ax=axs, density=False, histtype="step", label="resected triplets", linewidth=1.5, edgecolor="blue", color="aliceblue", zorder=0)

# plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$p_T$(GeV)', fontsize='20')
plt.ylabel('Entries', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useOffset=False, useMathText=True)
plt.gca().yaxis.get_offset_text().set_position((-0.06,1))
plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()
plt.yscale('log')
# plt.text(0.1, 150, "resolution $60<p_T<100$ \n    $\mu = 0.0065$\n    $\sigma = 0.0649$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
plt.savefig("figures/pt_distribution_logscale.pdf", dpi=150)

# %% [markdown]
# ## eta

# %%
eta_hist = file[file.keys()[1]]
eta_hist_val = eta_hist.values()
eta_hist_edges = eta_hist.axis().edges()

f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(eta_hist_val,  bins=eta_hist_edges, ax=axs, density=False, histtype="step", label="resected triplets", linewidth=1.5, edgecolor="red", color="coral", zorder=0, alpha=0.8)

# plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$\eta$  ', fontsize='20')
plt.ylabel('Entries', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useOffset=False, useMathText=True)
plt.gca().yaxis.get_offset_text().set_position((-0.06,1))
plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()
# plt.yscale('log')
# plt.text(0.1, 150, "resolution $60<p_T<100$ \n    $\mu = 0.0065$\n    $\sigma = 0.0649$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
plt.savefig("figures/eta_distribution.pdf", dpi=150)

# %% [markdown]
# ## phi

# %%
phi_hist = file[file.keys()[2]]
phi_hist_val = phi_hist.values()
phi_hist_edges = phi_hist.axis().edges()

f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(phi_hist_val,  bins=phi_hist_edges, ax=axs, density=False, histtype="step", label="resected triplets", linewidth=1.5, edgecolor="green", color="palegreen", zorder=0)

# plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$\phi$', fontsize='20')
plt.ylabel('Entries', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useOffset=False, useMathText=True)
plt.gca().yaxis.get_offset_text().set_position((-0.06,1))
plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()

# plt.text(0.1, 150, "resolution $60<p_T<100$ \n    $\mu = 0.0065$\n    $\sigma = 0.0649$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
plt.savefig("figures/phi_distribution.pdf", dpi=150)

# %% [markdown]
# ## N

# %%
file_name = "../histograms/hist_Npuppi.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
# Out:
# ['w3pi;1', 'neutrino;1', 'ttbar;1']
# {'w3pi;1': 'TH1D', 'neutrino;1': 'TH1D', 'ttbar;1': 'TH1D'}

# %%
w3pi_hist = file[file.keys()[0]]
neutrino_hist = file[file.keys()[1]]
ttbar_hist = file[file.keys()[2]]

w3pi_hist_val = w3pi_hist.values()
neutrino_hist_val = neutrino_hist.values()
ttbar_hist_val = ttbar_hist.values()

w3pi_hist_edges = w3pi_hist.axis().edges()
neutrino_hist_edges = neutrino_hist.axis().edges()
ttbar_hist_edges = ttbar_hist.axis().edges()

# %%
f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(w3pi_hist_val, bins=w3pi_hist_edges, ax=axs, density=True, histtype="step", label="w3pi", linewidth=1.6, edgecolor="blue", color="lightblue")
hep.histplot(neutrino_hist_val,  bins=neutrino_hist_edges, ax=axs, density=True, histtype="step", label="neutrino", linewidth=1.6, edgecolor="red")
hep.histplot(ttbar_hist_val,  bins=ttbar_hist_edges,  ax=axs, density=True, histtype="step", label="ttbar", linewidth=1.6, edgecolor="green")

plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('Event Multiplicity', fontsize='20')
plt.ylabel('Normalized Events', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='plain', scilimits=(0, 0), useOffset=False, useMathText=True)


plt.savefig("figures/Npuppi_distributions.pdf", dpi=150)
# Out:
# /home/pietro/anaconda3/envs/root-env/lib/python3.8/site-packages/mplhep/utils.py:240: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   self.errors()
# /home/pietro/anaconda3/envs/root-env/lib/python3.8/site-packages/mplhep/utils.py:240: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   self.errors()
# /home/pietro/anaconda3/envs/root-env/lib/python3.8/site-packages/mplhep/utils.py:240: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   self.errors()

# %% [markdown]
# # generated features

# %%
file_name = "../histograms/hist_generated.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
# Out:
# ['pt;1', 'eta;1', 'phi;1', 'Npuppi;1']
# {'pt;1': 'TH1F', 'eta;1': 'TH1F', 'phi;1': 'TH1F', 'Npuppi;1': 'TH1F'}

# %% [markdown]
# ## pt

# %%
pt_gen_hist = file[file.keys()[0]]
pt_gen_hist_val = pt_gen_hist.values()
pt_gen_hist_edges = pt_gen_hist.axis().edges()

f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(pt_gen_hist_val,  bins=pt_gen_hist_edges, ax=axs, density=False, histtype="step", label="gen pt", linewidth=1.5, edgecolor="purple", color="lightblue")
hep.histplot(pt_hist_val,  bins=pt_hist_edges, ax=axs, density=False, histtype="fill", label="pt", linewidth=1.5, edgecolor="blue", color="aliceblue", zorder=0)

plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$p_T$(GeV)', fontsize='20')
plt.ylabel('Entries', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useOffset=False, useMathText=True)
plt.gca().yaxis.get_offset_text().set_position((-0.06,1))
plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()
plt.yscale('log')
# plt.text(0.1, 150, "resolution $60<p_T<100$ \n    $\mu = 0.0065$\n    $\sigma = 0.0649$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
plt.savefig("figures/pt_distribution_gen.pdf", dpi=150)

# %% [markdown]
# ## eta

# %%
eta_gen_hist = file[file.keys()[1]]
eta_gen_hist_val = eta_gen_hist.values()
eta_gen_hist_edges = eta_gen_hist.axis().edges()

f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(eta_gen_hist_val,  bins=eta_gen_hist_edges, ax=axs, density=True, histtype="step", label="gen eta", linewidth=1.5, edgecolor="purple", color="lightblue")
hep.histplot(eta_hist_val,  bins=eta_hist_edges, ax=axs, density=True, histtype="fill", label="eta", linewidth=1.5, edgecolor="red", color="mistyrose", zorder=0)

plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$p_T$(GeV)', fontsize='20')
plt.ylabel('Entries', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useOffset=False, useMathText=True)
plt.gca().yaxis.get_offset_text().set_position((-0.06,1))
plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()
# plt.yscale('log')
# plt.text(0.1, 150, "resolution $60<p_T<100$ \n    $\mu = 0.0065$\n    $\sigma = 0.0649$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
plt.savefig("figures/eta_distribution_gen.pdf", dpi=150)
# Out:
# /home/pietro/anaconda3/envs/root-env/lib/python3.8/site-packages/mplhep/utils.py:240: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   self.errors()

# %% [markdown]
# ## phi

# %%
phi_gen_hist = file[file.keys()[2]]
phi_gen_hist_val = phi_gen_hist.values()
phi_gen_hist_edges = phi_gen_hist.axis().edges()

f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(phi_gen_hist_val,  bins=phi_gen_hist_edges, ax=axs, density=True, histtype="step", label="gen phi", linewidth=2, edgecolor="purple", color="lightblue")
hep.histplot(phi_hist_val,  bins=phi_hist_edges, ax=axs, density=True, histtype="fill", label="phi", linewidth=1, edgecolor="green", color="mintcream", zorder=0)

plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$p_T$(GeV)', fontsize='20')
plt.ylabel('Entries', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useOffset=False, useMathText=True)
plt.gca().yaxis.get_offset_text().set_position((-0.06,1))
plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()
# plt.yscale('log')
# plt.text(0.1, 150, "resolution $60<p_T<100$ \n    $\mu = 0.0065$\n    $\sigma = 0.0649$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
plt.savefig("figures/phi_distribution_gen.pdf", dpi=150)
# Out:
# /home/pietro/anaconda3/envs/root-env/lib/python3.8/site-packages/mplhep/utils.py:240: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   self.errors()
# /home/pietro/anaconda3/envs/root-env/lib/python3.8/site-packages/mplhep/utils.py:240: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   self.errors()

# %% [markdown]
# ## N

# %%
N_gen_hist = file[file.keys()[3]]
N_gen_hist_val = N_gen_hist.values()
N_gen_hist_edges = N_gen_hist.axis().edges()

# %%
f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(w3pi_hist_val, bins=w3pi_hist_edges, ax=axs, density=True, histtype="step", label="w3pi", linewidth=1.6, edgecolor="blue", color="lightblue")
hep.histplot(neutrino_hist_val,  bins=neutrino_hist_edges, ax=axs, density=True, histtype="step", label="neutrino", linewidth=1.6, edgecolor="red")
hep.histplot(ttbar_hist_val,  bins=ttbar_hist_edges,  ax=axs, density=True, histtype="step", label="ttbar", linewidth=1.6, edgecolor="green")
hep.histplot(N_gen_hist_val, bins=N_gen_hist_edges, ax=axs, density=True, histtype="fill", label="gen", linewidth=1.6, edgecolor="purple", color="thistle", zorder=0, alpha=0.6)

plt.legend(loc='upper right', frameon=False, title='$m_{3\pi}$ histogram', title_fontsize='20', fontsize='18')
plt.xlabel('Multiplicity', fontsize='20')
plt.ylabel('Normalized Events', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

plt.ticklabel_format(axis='y', style='plain', scilimits=(0, 0), useOffset=False, useMathText=True)


plt.savefig("figures/Npuppi_gen_distributions.pdf", dpi=150)
# Out:
# /home/pietro/anaconda3/envs/root-env/lib/python3.8/site-packages/mplhep/utils.py:240: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   self.errors()
# /home/pietro/anaconda3/envs/root-env/lib/python3.8/site-packages/mplhep/utils.py:240: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   self.errors()
# /home/pietro/anaconda3/envs/root-env/lib/python3.8/site-packages/mplhep/utils.py:240: UserWarning: Integer weights indicate poissonian data. Will calculate Garwood interval if ``scipy`` is installed. Otherwise errors will be set to ``sqrt(w2)``.
#   self.errors()
# ...

# %% [markdown]
# # Isolation

# %%
file_name = "../histograms/isolation.root"
file = uproot.open(file_name)
print(file.keys())
print(file.classnames())
# Out:
# ['signal;1', 'background;1']
# {'signal;1': 'TH1D', 'background;1': 'TH1D'}

# %%
signal = file[file.keys()[0]]
signal_val = signal.values()
signal_edges = signal.axis().edges()

background = file[file.keys()[1]]
background_val = background.values()
background_edges = background.axis().edges()

f, axs = plt.subplots(1,1, figsize=(12,10))

hep.style.use(hep.style.CMS)
hep.cms.label("",com = 13.6, rlabel="Phase-2 (14 Tev, 200 PU)",  fontsize=25, italic=(0,1))

hep.histplot(signal_val,  bins=signal_edges, ax=axs, density=False, histtype="step", label="signal", linewidth=1.5, edgecolor="tab:blue", color="lightblue")
hep.histplot(background_val,  bins=background_edges, ax=axs, density=False, histtype="step", label="background", linewidth=1.5, edgecolor="tab:orange", color="aliceblue", zorder=0)

plt.legend(loc='upper right', frameon=False, title='Isolation histogram', title_fontsize='20', fontsize='18')
plt.xlabel('$3^{rd}\pi$ isolation', fontsize='20')
plt.ylabel('Entries', fontsize='20')
plt.tick_params(axis='both', labelsize=18) 

# plt.ticklabel_format(axis='y', style='sci', scilimits=(0, 0), useOffset=False, useMathText=True)
# plt.gca().yaxis.get_offset_text().set_position((-0.06,1))
# plt.gca().yaxis.get_offset_text().set_fontsize(18)
# plt.show()

# plt.text(0.1, 150, "resolution $60<p_T<100$ \n    $\mu = 0.0065$\n    $\sigma = 0.0649$", fontsize=20,bbox=dict(facecolor='white',edgecolor="grey", boxstyle='round'))
plt.savefig("figures/isolation_third_pion.pdf", dpi=150)
